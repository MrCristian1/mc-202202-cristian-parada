# %% [markdown]
# <a href="https://colab.research.google.com/github/MrCristian1/mc-202202-cristian-parada/blob/main/Mctaller_20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import math
import matplotlib.pyplot as plt
import sympy as sym

xi = [0, 1, 2, 3, 4, 5, 6]
yi = [-0.9, 0, 2, 4.5, 8.3, 13, 18]
######################
xi = np.array(xi)
yi = np.array(yi)
n = len(xi)


####################
xm = np.mean(xi)
ym = np.mean(yi)
sx = np.sum(xi)
sy = np.sum(yi)
sxy = np.sum(xi*yi)
sx2 = np.sum(xi**2)
sx3 = np.sum(xi**3)
sx4 = np.sum(xi**4)
sy2 = np.sum(yi**2)

sxy2 = np.sum(xi**2*yi)

#######################

#a1 = (n*sxy-sx*sy)/(n*sx2-sx**2)
#a0 = ym - a1*xm




print(n,"a0 +", sx,"a1 +", sx2,"a2 = ", sy)
print(sx,"a0 +", sx2,"a1 + ", sx3,"a2 =", sxy)
print(sx2,"a0 + ", sx3,"a1 +", sx4,"a2 =", sxy2)







A = np.array([[n,sx,sx2],
              [sx,sx2,sx3],
              [sx2,sx3,sx4]])

B = np.array([[sy],
              [sxy],
              [sxy2]])

# PROCEDIMIENTO
casicero = 1e-15 # Considerar como 0

# Evitar truncamiento en operaciones
A = np.array(A,dtype=float) 

# Matriz aumentada
AB = np.concatenate((A,B),axis=1)
AB0 = np.copy(AB)

# Pivoteo por filas
tamano = np.shape(AB)
w = tamano[0]
ñ = tamano[1]

# Para cada fila en AB
for i in range(0,w-1,1):
    # columna desde diagonal i en adelante
    columna = abs(AB[i:,i])
    dmax = np.argmax(columna)
    
    # dmax no está en diagonal
    if (dmax !=0):
        # intercambia filas
        temporal = np.copy(AB[i,:])
        AB[i,:] = AB[dmax+i,:]
        AB[dmax+i,:] = temporal
        
AB1 = np.copy(AB)

# eliminacion hacia adelante
for i in range(0,w-1,1):
    pivote = AB[i,i]
    adelante = i + 1
    for k in range(adelante,w,1):
        factor = AB[k,i]/pivote
        AB[k,:] = AB[k,:] - AB[i,:]*factor
AB2 = np.copy(AB)

# elimina hacia atras
ufila = w-1
ucolumna = ñ-1
for i in range(ufila,0-1,-1):
    pivote = AB[i,i]
    atras = i-1 
    for k in range(atras,0-1,-1):
        factor = AB[k,i]/pivote
        AB[k,:] = AB[k,:] - AB[i,:]*factor
    # diagonal a unos
    AB[i,:] = AB[i,:]/AB[i,i]
X = np.copy(AB[:,ucolumna])
X = np.transpose([X])


# SALIDA
#print('Matriz aumentada:')
#print(AB0)
#print('Pivoteo parcial por filas')
#print(AB1)
#print('eliminacion hacia adelante')
#print(AB2)
#print('eliminación hacia atrás')
#print(AB)
print('solución de X: ')
print(X)

a0 = -0.94285714
a1 = 0.56428571
a2 = 0.43571429

print("Formula =", a0,"+", a1,"x +", a2,"x^2")






st=0



for i in range (n):
  st += (yi[i] - ym)**2



print('st:', st)

SY19= np.sqrt(st/6)

print('Desviacion estandar: ', SY19)

sr=0
for i in range (n):
  sr += (yi[i] - a0 - a1*xi[i]- a2*xi[i]**2)**2

print('sr: ', sr)



#Error estandar


SyDx = np.sqrt(sr/4)

print('Error estandar: ', SyDx)




#COEFICIENTE DE CORRELACION

r=np.sqrt((st-sr)/st)*100

print('Coeficiente de correlación:', r)


##########################
x = sym.Symbol('x')
f = a0 + a1*x

fx = sym.lambdify(x,f)
fi = fx(xi)

##########################
#print('ymedia =' ,ym)
#print('f = ' ,f)


#plt.plot(xi,yi,'o', label='(xi,yi)')
#plt.stem(xi,yi, bottom=ym)
#plt.plot(xi,fi, color = 'red', label=f)
#plt.xlabel('xi')
#plt.ylabel('yi')
#plt.legend()
#plt.show()
# Out:
# 7 a0 + 21 a1 + 91 a2 =  44.9
# 21 a0 + 91 a1 +  441 a2 = 223.7
# 91 a0 +  441 a1 + 2275 a2 = 1154.3
# solución de X:
# [[-0.94285714]
#  [ 0.56428571]
#  [ 0.43571429]]
# Formula = -0.94285714 + 0.56428571 x + 0.43571429 x^2
# st: 298.9485714285714
# Desviacion estandar:  7.058665731196081
# sr:  0.10857142857145671
# Error estandar:  0.16475089420960415
# Coeficiente de correlación: 99.98183947032744
