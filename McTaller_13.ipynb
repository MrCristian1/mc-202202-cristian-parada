# %% [markdown]
# <a href="https://colab.research.google.com/github/MrCristian1/mc-202202-cristian-parada/blob/main/McTaller_13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

VectorUno = []
VectorDos = []

Tamaño = int(input('Por favor indique la longitud de su primer y segundo vector:'))
for i in range (Tamaño):
  print("Ingrese el valor", i + 1,"del primer vector: ")
  Vector = int(input())
  VectorUno.append(Vector)

print("Vector: ", VectorUno)

for i in range (Tamaño):
  print("Ingrese el valor", i + 1,"del segundo vector: ")
  Vector = int(input())
  VectorDos.append(Vector)

print("Vector: ", VectorDos)

#Escalar
ProductoPunto = np.dot(VectorUno,VectorDos)

print("El producto punto entre ambos vectores es: ", ProductoPunto)
# Out:
# Por favor indique la longitud de su primer y segundo vector:3
# Ingrese el valor 1 del primer vector:
# 2
# Ingrese el valor 2 del primer vector:
# 4
# Ingrese el valor 3 del primer vector:
# 1
# Vector:  [2, 4, 1]
# Ingrese el valor 1 del segundo vector:
# 2
# Ingrese el valor 2 del segundo vector:
# 6
# Ingrese el valor 3 del segundo vector:
# 8
# Vector:  [2, 6, 8]
# El producto punto entre ambos vectores es:  36

# %% [markdown]
# #PUNTO 2

# %%
import numpy as np

def multiplicar3_matriz1(m1, m2):
  m5 = []
  for i in range(len(m1)):
    m5.append([])
    for j in range(len(m1[0])):
      m5[i].append(m1[i][j] * 3)
  return m5



def multiplicar4_matriz1(m1, m2):
  m6 = []
  for i in range(len(m1)):
    m6.append([])
    for j in range(len(m1[0])):
      m6[i].append(m1[i][j] * 4)
  return m6



filas = int(input('Introduzca el numero de filas para su matriz: '))
columnas = int(input('Introduzca el numero de columnas para su matriz: '))

matriz1 = []
for i in range(filas):
  matriz1.append([])
  for j in range(columnas):
    valor = int(input("Fila {}, Columna {} : ".format(i+1, j+1)))
    matriz1[i].append(valor)

#matriz1 = np.array(valor).reshape(filas,columnas)

print()
for fila in matriz1:
  print("[", end=" ")
  for elemento in fila:
    print("{:8.2f}" .format(elemento), end=" ")
  print("]")
print()


#########################################################################################
#Matriz 2
print("REALIZA EL MISMO PROCESO CON TÚ SEGUNDA MATRIZ")

filas2 = int(input('Introduzca el numero de filas para su matriz: '))
columnas2 = int(input('Introduzca el numero de columnas para su matriz: '))

matriz2 = []
for i in range(filas2):
  matriz2.append([])
  for j in range(columnas2):
    valor2 = int(input("Fila {}, Columna {} : ".format(i+1, j+1)))
    matriz2[i].append(valor2)

print()
for fila2 in matriz2:
  print("[", end=" ")
  for elemento2 in fila2:
    print("{:8.2f}" .format(elemento2), end=" ")
  print("]")
print()

g = multiplicar3_matriz1(matriz1,3)
v = multiplicar3_matriz1(matriz2, 4)

def pedirNumeroEntero():
 
    correcto=False
    num=0
    while(not correcto):
        try:
            num = int(input("Introduce un numero entero: "))
            correcto=True
        except ValueError:
            print('Error, introduce un numero entero')
     
    return num

salir = False
eligio = 0



while not salir:
    print("Teniendo en cuenta las 2 matrices, que operación desea realizar? - Tenga en cuenta que la primera matriz es la (A) y la segunda es la (B)")

    print ("1. 3A")
    print ("2. 4B")
    print ("3. A + B")
    print ("4. B x A")
    print ("5. Salir")
    print ()
    print ("Elige una opción")
    print ()


    eligio = pedirNumeroEntero()

    if eligio==1:    

        for fila in g:
          print("[", end=" ")
          for elemento in fila:
            print(elemento, end=" ")
          print("]")
        

    elif eligio==2:

        for fila in v:
          print("[", end=" ")
          for elemento in fila:
            print(elemento, end=" ")
          print("]")


    elif eligio==3:
      def sumar_matrices(matriz1, matriz2):
        if len(matriz1) == len(matriz2) and len(matriz1[0]) == len(matriz2[0]):
          m3 = []
          for i in range (len(matriz1)):
            m3.append([])
            for j in range(len(matriz1[0])):
              m3[i].append(matriz1[i] [j] + matriz2[i] [j])
          return m3
        else:
          return None

      c= sumar_matrices(matriz1,matriz2)
      if c ==None:
        print("No se puede sumar")
      else:
        for fila in c:
          print("[", end=" ")
          for elemento in fila:
            print(elemento, end=" ")
          print("]")

              

    elif eligio==4:
      def multiplicar_matrices(matriz1, matriz2):
        if len(matriz1[0]) == len(matriz2):
          m4 = []
          for i in range (len(matriz1)):
            m4.append([])
            for j in range(len(matriz2[0])):
              m4[i].append(0)
          for i in range(len(matriz1)):
            for j in range(len(matriz2[0])):
              for k in range(len(matriz1[0])):
                m4[i][j] += matriz1[i][k] * matriz2[i][k]
          return m4
        else:
          return None

      d= multiplicar_matrices(matriz1,matriz2)
      if d ==None:
        print("No se puede multiplicar")
      else:
        for fila in d:
          print("[", end=" ")
          for elemento in fila:
            print(elemento, end=" ")
          print("]")

    elif eligio==5:
      salir = True
    else:
      print("Opción no válida")
print("Fin")
# Out:
# Introduzca el numero de filas para su matriz: 2
# Introduzca el numero de columnas para su matriz: 2
# Fila 1, Columna 1 : 6
# Fila 1, Columna 2 : 5
# Fila 2, Columna 1 : 4
# Fila 2, Columna 2 : 3
#
# [     6.00     5.00 ]
# [     4.00     3.00 ]
#
# REALIZA EL MISMO PROCESO CON TÚ SEGUNDA MATRIZ
# Introduzca el numero de filas para su matriz: 2
# Introduzca el numero de columnas para su matriz: 2
# Fila 1, Columna 1 : 8
# Fila 1, Columna 2 : 9
# Fila 2, Columna 1 : 7
# Fila 2, Columna 2 : 5
#
# [     8.00     9.00 ]
# [     7.00     5.00 ]
#
# Teniendo en cuenta las 2 matrices, que operación desea realizar? - Tenga en cuenta que la primera matriz es la (A) y la segunda es la (B)
# 1. 3A
# 2. 4B
# 3. A + B
# 4. B x A
# 5. Salir
#
# Elige una opción
#
# Introduce un numero entero: 1
# [ 18 15 ]
# [ 12 9 ]
# Teniendo en cuenta las 2 matrices, que operación desea realizar? - Tenga en cuenta que la primera matriz es la (A) y la segunda es la (B)
# 1. 3A
# 2. 4B
# 3. A + B
# 4. B x A
# ...
