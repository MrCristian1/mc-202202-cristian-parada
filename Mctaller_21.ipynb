# %% [markdown]
# <a href="https://colab.research.google.com/github/MrCristian1/mc-202202-cristian-parada/blob/main/Mctaller_21.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import math
import matplotlib.pyplot as plt
import sympy as sym

xi = [1, 1, 2, 3, 1, 2, 3, 3]
xi2 = [-1, 0, 0, 1, 1, 2, 2, 0]
yi = [1.6, 3, 1.1, 1.2, 3.2, 3.3, 1.7, 0.1]
######################
xi = np.array(xi)
xi2 = np.array(xi2)
yi = np.array(yi)
n = len(xi)


####################
xm = np.mean(xi)
ym = np.mean(yi)
sx = np.sum(xi)
sxx2 = np.sum(xi2)
sy = np.sum(yi)
sxy = np.sum(xi*yi)
sxxi2 = np.sum(xi*xi2)
sxy2 = np.sum(xi2*yi)
sxi = np.sum(xi**2)
sxi2 = np.sum(xi2**2)
#sx4 = np.sum(xi**4) #quitar
#sy2 = np.sum(yi**2)#quitar

#sxy2 = np.sum(xi**2*yi)#quitar

#######################

#a1 = (n*sxy-sx*sy)/(n*sx2-sx**2)
#a0 = ym - a1*xm

print("ECUACIONES:")

print(n,"a0 +", sx,"a1 +", sxx2,"a2 = ", sy)
print(sx,"a0 +", sxi,"a1 + ", sxxi2,"a2 =", sxy)
print(sxx2,"a0 + ", sxxi2,"a1 +", sxi2,"a2 =", sxy2)







A = np.array([[n,sx,sxx2],
              [sx,sxi,sxxi2],
              [sxx2,sxxi2,sxi2]])

B = np.array([[sy],
              [sxy],
              [sxy2]])

# PROCEDIMIENTO
casicero = 1e-15 # Considerar como 0

# Evitar truncamiento en operaciones
A = np.array(A,dtype=float) 

# Matriz aumentada
AB = np.concatenate((A,B),axis=1)
AB0 = np.copy(AB)

# Pivoteo por filas
tamano = np.shape(AB)
w = tamano[0]
ñ = tamano[1]

# Para cada fila en AB
for i in range(0,w-1,1):
    # columna desde diagonal i en adelante
    columna = abs(AB[i:,i])
    dmax = np.argmax(columna)
    
    # dmax no está en diagonal
    if (dmax !=0):
        # intercambia filas
        temporal = np.copy(AB[i,:])
        AB[i,:] = AB[dmax+i,:]
        AB[dmax+i,:] = temporal
        
AB1 = np.copy(AB)

# eliminacion hacia adelante
for i in range(0,w-1,1):
    pivote = AB[i,i]
    adelante = i + 1
    for k in range(adelante,w,1):
        factor = AB[k,i]/pivote
        AB[k,:] = AB[k,:] - AB[i,:]*factor
AB2 = np.copy(AB)

# elimina hacia atras
ufila = w-1
ucolumna = ñ-1
for i in range(ufila,0-1,-1):
    pivote = AB[i,i]
    atras = i-1 
    for k in range(atras,0-1,-1):
        factor = AB[k,i]/pivote
        AB[k,:] = AB[k,:] - AB[i,:]*factor
    # diagonal a unos
    AB[i,:] = AB[i,:]/AB[i,i]
X = np.copy(AB[:,ucolumna])
X = np.transpose([X])


# SALIDA
#print('Matriz aumentada:')
#print(AB0)
#print('Pivoteo parcial por filas')
#print(AB1)
#print('eliminacion hacia adelante')
#print(AB2)
#print('eliminación hacia atrás')
#print(AB)
print('solución de X: ')
print(X)

a0 = 3.83529412
a1 = -1.24705882
a2 = 0.89411765

print("Formula =", a0, a1,"x" "+" , a2,"x2")






st=0



for i in range (n):
  st += (yi[i] - ym)**2



print('st:', st)

#SY19= np.sqrt(st/6)

#print('Desviacion estandar: ', SY19)

sr=0
for i in range (n):
  sr += (yi[i] - a0 - a1*xi[i]- a2*xi2[i])**2

print('sr: ', sr)



#Error estandar


#SyDx = np.sqrt(sr/4)

#print('Error estandar: ', SyDx)




#COEFICIENTE DE CORRELACION

r=np.sqrt((st-sr)/st)*100

print('Coeficiente de correlación:', r)


##########################
x = sym.Symbol('x')
f = a0 + a1*x

fx = sym.lambdify(x,f)
fi = fx(xi)

##########################
#print('ymedia =' ,ym)
#print('f = ' ,f)


#plt.plot(xi,yi,'o', label='(xi,yi)')
#plt.stem(xi,yi, bottom=ym)
#plt.plot(xi,fi, color = 'red', label=f)
#plt.xlabel('xi')
#plt.ylabel('yi')
#plt.legend()
#plt.show()
# Out:
# ECUACIONES:
# 8 a0 + 16 a1 + 5 a2 =  15.2
# 16 a0 + 38 a1 +  13 a2 = 25.599999999999998
# 5 a0 +  13 a1 + 11 a2 = 12.8
# solución de X:
# [[ 3.83529412]
#  [-1.24705882]
#  [ 0.89411765]]
# Formula = 3.83529412 -1.24705882 x+ 0.89411765 x2
# st: 9.36
# sr:  0.4235294117647069
# Coeficiente de correlación: 97.71136736438189
